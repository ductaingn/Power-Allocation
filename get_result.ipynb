# %%
from helper import get_log_from_wandb
from process_results import plot_interface_usage, get_result_table
import matplotlib.pyplot as plt
import os
font = {'size': 20}
plt.rc('font', **font)

# %%
PATH = 'Figures'
def get_results(run_ids:list[str], num_devices:int, save_path_prefix:str):
    run_dfs = []
    for run_id in run_ids:
        run_df, run = get_log_from_wandb(run_id, return_run=True)
        run_dfs.append(run_df)

        print(run_df["Algorithm"].iloc[0])
        plot_interface_usage(run_df, num_devices, save_path=os.path.join(save_path_prefix, f'InterfaceUsage{run_df['Algorithm'].iloc[0]}.pdf'))
    
    table = get_result_table(run_dfs, num_devices, save_path=os.path.join(save_path_prefix, 'Result.csv'))
    print(table)

    return run_dfs, table

# %% [markdown]
# # Scenario 1

# %% [markdown]
# ## 5 dBm

# %%
run_dfs, result_table = get_results(
    run_ids=[
        "42m5wqi2", # Random
        "dkkeupts", # RAQL
        "6evw1g8d", # SACPF
        "q3kna3u4", # SACPA
    ],
    num_devices=10,
    save_path_prefix=os.path.join(PATH, 'scenario1/5dbm')
)
# Out:
# Random
# Plot saved to Figures/scenario1/5dbm/InterfaceUsageRandom.pdf
# RAQL
# Plot saved to Figures/scenario1/5dbm/InterfaceUsageRAQL.pdf
# SACPF
# Plot saved to Figures/scenario1/5dbm/InterfaceUsageSACPF.pdf
# SACPA
# Plot saved to Figures/scenario1/5dbm/InterfaceUsageSACPA.pdf
# Plot saved to Figures/scenario1/5dbm/Result.csv
#                           0         1         2         3
#     Algorithm        Random      RAQL     SACPF     SACPA
#     Reward       -21.284149 -3.396776  7.494279  8.610894
#     Avg. Success   0.511222  0.896845  0.979047  0.988493
# PLR D1             0.179135  0.033413       0.0       0.0
#     D2             0.689837  0.515868  0.142183    0.0868
#     D3             0.488439  0.370757  0.000288  0.000091
#     D4             0.439051  0.306301       0.0       0.0
#     D5             0.461245  0.345245       0.0       0.0
#     D6             0.890286  0.760126   0.36215    0.2067
#     D7             0.359652  0.173467       0.0       0.0
#     D8             0.477295  0.359026       0.0       0.0
#     D9             0.377458   0.19974       0.0       0.0
#     D10            0.451987  0.331933       0.0       0.0
#     Δ̄ρ           -0.381438 -0.239588  0.049538  0.070641

# %% [markdown]
# ## 1 dBm

# %%
run_dfs, result_table = get_results(
    run_ids=[
        "1gca94kw", # Random
        "bg79q8ql", # RAQL
        "zsizc9ra", # SACPF
        "xdi4v7ej", # SACPA
    ],
    num_devices=10,
    save_path_prefix=os.path.join(PATH, 'scenario1/1dbm')
)
# Out:
# Random
# Plot saved to Figures/scenario1/1dbm/InterfaceUsageRandom.pdf
# RAQL
# Plot saved to Figures/scenario1/1dbm/InterfaceUsageRAQL.pdf
# SACPF
# Plot saved to Figures/scenario1/1dbm/InterfaceUsageSACPF.pdf
# SACPA
# Plot saved to Figures/scenario1/1dbm/InterfaceUsageSACPA.pdf
# Plot saved to Figures/scenario1/1dbm/Result.csv
#                           0         1         2         3
#     Algorithm        Random      RAQL     SACPF     SACPA
#     Reward       -21.731312  -5.87084  5.129804   6.48754
#     Avg. Success    0.47056   0.87806   0.93658  0.979839
# PLR D1             0.250884  0.056626       0.0       0.0
#     D2             0.764748  0.581658    0.1944  0.103833
#     D3             0.489472  0.377918       1.0   0.00028
#     D4             0.476905   0.36493  0.000107       0.0
#     D5             0.481767  0.365067   0.00017  0.000049
#     D6             0.954101  0.917892    0.6739    0.6081
#     D7             0.426928  0.286669       0.0       0.0
#     D8             0.486536  0.366877  0.000205  0.000075
#     D9             0.441941  0.316992       0.0       0.0
#     D10            0.482364  0.378428  0.000114  0.000029
#     Δ̄ρ           -0.425565 -0.301305  -0.08689  0.028763

# %% [markdown]
# # Scenario 2

# %% [markdown]
# ## 5 dBm

# %%
run_dfs, result_table = get_results(
    run_ids=[
        "zfi5g7gb", # Random
        "omggbwz1", # RAQL
        "gb05q4ug", # SACPF
        "x415gb3y", # SACPA
    ],
    num_devices=15,
    save_path_prefix=os.path.join(PATH, 'scenario2/5dbm')
)
# Out:
# Random
# Plot saved to Figures/scenario2/5dbm/InterfaceUsageRandom.pdf
# RAQL
# Plot saved to Figures/scenario2/5dbm/InterfaceUsageRAQL.pdf
# SACPF
# Plot saved to Figures/scenario2/5dbm/InterfaceUsageSACPF.pdf
# SACPA
# Plot saved to Figures/scenario2/5dbm/InterfaceUsageSACPA.pdf
# Plot saved to Figures/scenario2/5dbm/Result.csv
#                          0         1         2         3
#     Algorithm       Random      RAQL     SACPF     SACPA
#     Reward        -22.8753 -8.184226   8.97185  8.180503
#     Avg. Success  0.438364  0.875325  0.959919  0.970156
# PLR D1             0.21008  0.031443       0.0       0.0
#     D2            0.721149   0.53077  0.121583  0.125933
#     D3            0.484278  0.369307    0.0005  0.000155
#     D4            0.460378  0.304902       0.0       0.0
#     D5            0.472149  0.348535  0.000057       0.0
#     D6            0.919321  0.763026    0.4941    0.2897
#     D7             0.40116  0.168697       0.0       0.0
#     D8            0.484523  0.362456  0.000143       0.0
#     D9            0.408159   0.19508       0.0       0.0
#     D10           0.463178  0.319542       0.0       0.0
#     D11           0.991217  0.975348    0.9394    0.8598
#     D12           0.466655  0.319342       0.0       0.0
#     D13           0.483006  0.353385  0.000118  0.000043
#     D14           0.919184  0.755576     0.479    0.3064
#     D15           0.484688  0.377418  0.000449   0.00011
#     Δ̄ρ          -0.457942 -0.311655  -0.03569 -0.005476

# %% [markdown]
# ## 1 dBm

# %%
run_dfs, result_table = get_results(
    run_ids=[
        "w50pd39l", # Random
        "o0mcwh6o", # RAQL
        "yncwzid9", # SACPF
        "1gcjc8fe", # SACPA
    ],
    num_devices=15,
    save_path_prefix=os.path.join(PATH, 'scenario2/1dbm')
)
# Out:
# Random
# Plot saved to Figures/scenario2/1dbm/InterfaceUsageRandom.pdf
# RAQL
# Plot saved to Figures/scenario2/1dbm/InterfaceUsageRAQL.pdf
# SACPF
# Plot saved to Figures/scenario2/1dbm/InterfaceUsageSACPF.pdf
# SACPA
# Plot saved to Figures/scenario2/1dbm/InterfaceUsageSACPA.pdf
# Plot saved to Figures/scenario2/1dbm/Result.csv
#                           0          1         2         3
#     Algorithm        Random       RAQL     SACPF     SACPA
#     Reward       -23.339794 -10.693113  0.228774  5.339922
#     Avg. Success   0.410227   0.856701  0.829699   0.95139
# PLR D1             0.286687   0.057976       0.0       0.0
#     D2             0.798563   0.578858    0.1391   0.15705
#     D3             0.486457   0.375258       1.0  0.001158
#     D4             0.483545   0.365387  0.000302       0.0
#     D5             0.482628   0.368307  0.000563  0.000095
#     D6             0.973821   0.919792    0.8159    0.7308
#     D7             0.457544   0.296003   0.00002       0.0
#     D8             0.488002   0.368807    0.9999  0.000295
#     D9              0.46005   0.312191       0.0       0.0
#     D10            0.481512   0.362046   0.00005   0.00007
#     D11            0.999837     0.9994    0.9984    0.9846
#     D12            0.486106   0.364626  0.000192  0.000058
#     D13             0.48642   0.358786    0.9999  0.000207
#     D14            0.974573   0.912991    0.8159     0.726
#     D15            0.486282   0.382318       1.0  0.000515
#     Δ̄ρ           -0.488802  -0.368183 -0.351348  -0.07339
